# %% [markdown]
# # Installing the OpenBB Platform in Google Colab
#
# This notebook will install the OpenBB Platform, fetch some data and prepare it for display as a bar chart.
#
# Sign up for a free account here: https://my.openbb.co

# %%
# Install the OpenBB Platform with all available extensions.
# Messages indicating package version conflicts at the end of installation can be safely ignored.

# !pip install openbb[all]

# There is also a nightly distribution available, openbb-nightly
# Out:
# Requirement already satisfied: openbb[all] in /usr/local/lib/python3.12/dist-packages (4.5.0)
# Requirement already satisfied: openbb-alpha-vantage<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-benzinga<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-biztoc<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-bls<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.2.0)
# Requirement already satisfied: openbb-cboe<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-cftc<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.2.0)
# Requirement already satisfied: openbb-charting<3.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (2.4.0)
# Requirement already satisfied: openbb-commodity<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-congress-gov<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.1.0)
# Requirement already satisfied: openbb-core<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.2)
# Requirement already satisfied: openbb-crypto<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-currency<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-deribit<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.1.0)
# Requirement already satisfied: openbb-derivatives<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-ecb<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-econdb<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-econometrics<2.0.0,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.6.0)
# Requirement already satisfied: openbb-economy<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-equity<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-etf<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-famafrench<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.1.0)
# Requirement already satisfied: openbb-federal-reserve<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-finra<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-finviz<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-fixedincome<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-fmp<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.1)
# Requirement already satisfied: openbb-fred<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-government-us<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-imf<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.2.0)
# Requirement already satisfied: openbb-index<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-intrinio<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-mcp-server<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.2.0)
# Requirement already satisfied: openbb-multpl<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.2.0)
# Requirement already satisfied: openbb-nasdaq<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-news<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-oecd<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-platform-api<2.0.0,>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.2.1)
# Requirement already satisfied: openbb-polygon<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-quantitative<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-regulators<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-sec<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-seeking-alpha<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-stockgrid<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-technical<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-tiingo<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-tmx<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-tradier<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-tradingeconomics<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-us-eia<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.2.0)
# Requirement already satisfied: openbb-wsj<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: openbb-yfinance<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from openbb[all]) (1.5.0)
# Requirement already satisfied: aiohttp-client-cache<0.12.0,>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from openbb-cboe<2.0.0,>=1.5.0->openbb[all]) (0.11.1)
# Requirement already satisfied: aiosqlite<0.21.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from openbb-cboe<2.0.0,>=1.5.0->openbb[all]) (0.20.0)
# Requirement already satisfied: nbformat<6.0.0,>=5.10.0 in /usr/local/lib/python3.12/dist-packages (from openbb-charting<3.0.0,>=2.4.0->openbb[all]) (5.10.4)
# Requirement already satisfied: pandas-ta-openbb<0.5.0,>=0.4.22 in /usr/local/lib/python3.12/dist-packages (from openbb-charting<3.0.0,>=2.4.0->openbb[all]) (0.4.22)
# Requirement already satisfied: plotly<7.0.0,>=6.3.1 in /usr/local/lib/python3.12/dist-packages (from openbb-charting<3.0.0,>=2.4.0->openbb[all]) (6.3.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.12.15 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb[all]) (3.13.0)
# Requirement already satisfied: fastapi<0.117.0,>=0.116.2 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb[all]) (0.116.2)
# Requirement already satisfied: html5lib<2.0,>=1.1 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb[all]) (1.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb[all]) (8.7.0)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb[all]) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.9 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb[all]) (2.11.10)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb[all]) (2.10.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb[all]) (1.1.1)
# Requirement already satisfied: python-multipart<0.0.21,>=0.0.20 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb[all]) (0.0.20)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb[all]) (2.32.5)
# Requirement already satisfied: ruff<0.14,>=0.13 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb[all]) (0.13.3)
# Requirement already satisfied: uuid7<0.2.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb[all]) (0.1.0)
# Requirement already satisfied: uvicorn<0.36.0,>=0.35.0 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb[all]) (0.35.0)
# Requirement already satisfied: websockets<16.0,>=15.0 in /usr/local/lib/python3.12/dist-packages (from openbb-core<2.0.0,>=1.5.1->openbb[all]) (15.0.1)
# Requirement already satisfied: async-lru<3.0.0,>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from openbb-deribit<2.0.0,>=1.1.0->openbb[all]) (2.0.5)
# Requirement already satisfied: xmltodict<0.14.0,>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from openbb-ecb<2.0.0,>=1.5.0->openbb[all]) (0.13.0)
# Requirement already satisfied: arch<8.0,>=7.2 in /usr/local/lib/python3.12/dist-packages (from openbb-econometrics<2.0.0,>=1.6.0->openbb[all]) (7.2.0)
# Requirement already satisfied: linearmodels<7,>=6 in /usr/local/lib/python3.12/dist-packages (from openbb-econometrics<2.0.0,>=1.6.0->openbb[all]) (6.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.13.4 in /usr/local/lib/python3.12/dist-packages (from openbb-federal-reserve<2.0.0,>=1.5.0->openbb[all]) (4.13.5)
# Requirement already satisfied: finvizfinance<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from openbb-finviz<2.0.0,>=1.4.0->openbb[all]) (1.2.0)
# Requirement already satisfied: random-user-agent<2.0.0,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from openbb-government-us<2.0.0,>=1.5.0->openbb[all]) (1.0.1)
# Requirement already satisfied: requests-cache<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from openbb-intrinio<2.0.0,>=1.5.0->openbb[all]) (1.2.1)
# Requirement already satisfied: fastmcp>=2.12.3 in /usr/local/lib/python3.12/dist-packages (from openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (2.12.5)
# Requirement already satisfied: nasdaq-data-link<2.0.0,>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from openbb-nasdaq<2.0.0,>=1.5.0->openbb[all]) (1.0.4)
# Requirement already satisfied: defusedxml<0.9.0,>=0.8.0rc2 in /usr/local/lib/python3.12/dist-packages (from openbb-oecd<2.0.0,>=1.5.0->openbb[all]) (0.8.0rc2)
# Requirement already satisfied: urllib3>1.26.16 in /usr/local/lib/python3.12/dist-packages (from openbb-oecd<2.0.0,>=1.5.0->openbb[all]) (2.5.0)
# Requirement already satisfied: deepdiff>=8.6.1 in /usr/local/lib/python3.12/dist-packages (from openbb-platform-api<2.0.0,>=1.2.1->openbb[all]) (8.6.1)
# Requirement already satisfied: inscriptis<3.0.0,>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from openbb-sec<2.0.0,>=1.5.0->openbb[all]) (2.6.0)
# Requirement already satisfied: lxml<6.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from openbb-sec<2.0.0,>=1.5.0->openbb[all]) (5.4.0)
# Requirement already satisfied: trafilatura<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from openbb-sec<2.0.0,>=1.5.0->openbb[all]) (2.0.0)
# Requirement already satisfied: pytest-freezegun<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from openbb-stockgrid<2.0.0,>=1.5.0->openbb[all]) (0.4.2)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from openbb-technical<2.0.0,>=1.5.0->openbb[all]) (1.6.1)
# Requirement already satisfied: exchange-calendars<5.0.0,>=4.5.4 in /usr/local/lib/python3.12/dist-packages (from openbb-tmx<2.0.0,>=1.4.0->openbb[all]) (4.11.2)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from openbb-us-eia<2.0.0,>=1.2.0->openbb[all]) (3.1.5)
# Requirement already satisfied: xlrd<3.0.0,>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from openbb-us-eia<2.0.0,>=1.2.0->openbb[all]) (2.0.2)
# Requirement already satisfied: curl-adapter>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from openbb-yfinance<2.0.0,>=1.5.0->openbb[all]) (1.1.0)
# Requirement already satisfied: yfinance==0.2.58 in /usr/local/lib/python3.12/dist-packages (from openbb-yfinance<2.0.0,>=1.5.0->openbb[all]) (0.2.58)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.5.0->openbb[all]) (2.0.2)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.5.0->openbb[all]) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.5.0->openbb[all]) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.5.0->openbb[all]) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.5.0->openbb[all]) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.5.0->openbb[all]) (3.18.2)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.5.0->openbb[all]) (0.13.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.12.15->openbb-core<2.0.0,>=1.5.1->openbb[all]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.12.15->openbb-core<2.0.0,>=1.5.1->openbb[all]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.12.15->openbb-core<2.0.0,>=1.5.1->openbb[all]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.12.15->openbb-core<2.0.0,>=1.5.1->openbb[all]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.12.15->openbb-core<2.0.0,>=1.5.1->openbb[all]) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.12.15->openbb-core<2.0.0,>=1.5.1->openbb[all]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.12.15->openbb-core<2.0.0,>=1.5.1->openbb[all]) (1.22.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-cboe<2.0.0,>=1.5.0->openbb[all]) (2.2.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /usr/local/lib/python3.12/dist-packages (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-cboe<2.0.0,>=1.5.0->openbb[all]) (1.4.3)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.12/dist-packages (from aiosqlite<0.21.0,>=0.20.0->openbb-cboe<2.0.0,>=1.5.0->openbb[all]) (4.15.0)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.12/dist-packages (from arch<8.0,>=7.2->openbb-econometrics<2.0.0,>=1.6.0->openbb[all]) (1.15.3)
# Requirement already satisfied: statsmodels>=0.12 in /usr/local/lib/python3.12/dist-packages (from arch<8.0,>=7.2->openbb-econometrics<2.0.0,>=1.6.0->openbb[all]) (0.14.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.13.4->openbb-federal-reserve<2.0.0,>=1.5.0->openbb[all]) (2.8)
# Requirement already satisfied: pycurl>=7.45.5 in /usr/local/lib/python3.12/dist-packages (from curl-adapter>=1.1.0->openbb-yfinance<2.0.0,>=1.5.0->openbb[all]) (7.45.7)
# Requirement already satisfied: brotli in /usr/local/lib/python3.12/dist-packages (from curl-adapter>=1.1.0->openbb-yfinance<2.0.0,>=1.5.0->openbb[all]) (1.1.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from deepdiff>=8.6.1->openbb-platform-api<2.0.0,>=1.2.1->openbb[all]) (5.5.0)
# Requirement already satisfied: pyluach>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from exchange-calendars<5.0.0,>=4.5.4->openbb-tmx<2.0.0,>=1.4.0->openbb[all]) (2.3.0)
# Requirement already satisfied: toolz>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from exchange-calendars<5.0.0,>=4.5.4->openbb-tmx<2.0.0,>=1.4.0->openbb[all]) (1.1.0)
# Requirement already satisfied: tzdata>=2025.2 in /usr/local/lib/python3.12/dist-packages (from exchange-calendars<5.0.0,>=4.5.4->openbb-tmx<2.0.0,>=1.4.0->openbb[all]) (2025.2)
# Requirement already satisfied: korean_lunar_calendar>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from exchange-calendars<5.0.0,>=4.5.4->openbb-tmx<2.0.0,>=1.4.0->openbb[all]) (0.3.1)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi<0.117.0,>=0.116.2->openbb-core<2.0.0,>=1.5.1->openbb[all]) (0.48.0)
# Requirement already satisfied: authlib>=1.5.2 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (1.6.5)
# Requirement already satisfied: cyclopts>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (4.0.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (1.3.0)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (0.28.1)
# Requirement already satisfied: mcp<1.17.0,>=1.12.4 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (1.16.0)
# Requirement already satisfied: openapi-core>=0.19.5 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (0.19.5)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (0.5.1)
# Requirement already satisfied: pyperclip>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (1.11.0)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (13.9.4)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.12/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.5.1->openbb[all]) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.5.1->openbb[all]) (0.5.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->openbb-core<2.0.0,>=1.5.1->openbb[all]) (3.23.0)
# Requirement already satisfied: mypy-extensions>=0.4 in /usr/local/lib/python3.12/dist-packages (from linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.6.0->openbb[all]) (1.1.0)
# Requirement already satisfied: Cython>=3.0.10 in /usr/local/lib/python3.12/dist-packages (from linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.6.0->openbb[all]) (3.0.12)
# Requirement already satisfied: pyhdfe>=0.1 in /usr/local/lib/python3.12/dist-packages (from linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.6.0->openbb[all]) (0.2.0)
# Requirement already satisfied: formulaic>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.6.0->openbb[all]) (1.2.1)
# Requirement already satisfied: setuptools-scm<9.0.0,>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.6.0->openbb[all]) (8.3.1)
# Requirement already satisfied: inflection>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from nasdaq-data-link<2.0.0,>=1.0.4->openbb-nasdaq<2.0.0,>=1.5.0->openbb[all]) (0.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from nasdaq-data-link<2.0.0,>=1.0.4->openbb-nasdaq<2.0.0,>=1.5.0->openbb[all]) (2.9.0.post0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from nasdaq-data-link<2.0.0,>=1.0.4->openbb-nasdaq<2.0.0,>=1.5.0->openbb[all]) (10.8.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.4.0->openbb[all]) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.4.0->openbb[all]) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.4.0->openbb[all]) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.4.0->openbb[all]) (5.7.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl<4.0.0,>=3.1.5->openbb-us-eia<2.0.0,>=1.2.0->openbb[all]) (2.0.0)
# Requirement already satisfied: numba>=0.61.0 in /usr/local/lib/python3.12/dist-packages (from pandas-ta-openbb<0.5.0,>=0.4.22->openbb-charting<3.0.0,>=2.4.0->openbb[all]) (0.62.1)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly<7.0.0,>=6.3.1->openbb-charting<3.0.0,>=2.4.0->openbb[all]) (2.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly<7.0.0,>=6.3.1->openbb-charting<3.0.0,>=2.4.0->openbb[all]) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.9->openbb-core<2.0.0,>=1.5.1->openbb[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.9->openbb-core<2.0.0,>=1.5.1->openbb[all]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.9->openbb-core<2.0.0,>=1.5.1->openbb[all]) (0.4.2)
# Requirement already satisfied: freezegun>0.3 in /usr/local/lib/python3.12/dist-packages (from pytest-freezegun<0.5.0,>=0.4.2->openbb-stockgrid<2.0.0,>=1.5.0->openbb[all]) (1.5.5)
# Requirement already satisfied: pytest>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from pytest-freezegun<0.5.0,>=0.4.2->openbb-stockgrid<2.0.0,>=1.5.0->openbb[all]) (8.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->openbb-core<2.0.0,>=1.5.1->openbb[all]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->openbb-core<2.0.0,>=1.5.1->openbb[all]) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->openbb-core<2.0.0,>=1.5.1->openbb[all]) (2025.10.5)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache<2.0.0,>=1.1.0->openbb-intrinio<2.0.0,>=1.5.0->openbb[all]) (25.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0.0,>=1.6.0->openbb-technical<2.0.0,>=1.5.0->openbb[all]) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0.0,>=1.6.0->openbb-technical<2.0.0,>=1.5.0->openbb[all]) (3.6.0)
# Requirement already satisfied: courlan>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb[all]) (1.3.2)
# Requirement already satisfied: htmldate>=1.9.2 in /usr/local/lib/python3.12/dist-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb[all]) (1.9.3)
# Requirement already satisfied: justext>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb[all]) (3.0.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn<0.36.0,>=0.35.0->openbb-core<2.0.0,>=1.5.1->openbb[all]) (8.3.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn<0.36.0,>=0.35.0->openbb-core<2.0.0,>=1.5.1->openbb[all]) (0.16.0)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from authlib>=1.5.2->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (43.0.3)
# Requirement already satisfied: babel>=2.16.0 in /usr/local/lib/python3.12/dist-packages (from courlan>=1.3.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb[all]) (2.17.0)
# Requirement already satisfied: tld>=0.13 in /usr/local/lib/python3.12/dist-packages (from courlan>=1.3.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb[all]) (0.13.1)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.5.0->openbb[all]) (2.0.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=3.0.0->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=3.0.0->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (1.3.2)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=1.0.0->linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.6.0->openbb[all]) (1.3.0)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=1.0.0->linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.6.0->openbb[all]) (1.17.3)
# Requirement already satisfied: dateparser>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb[all]) (1.2.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (1.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.4.0->openbb[all]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.4.0->openbb[all]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.4.0->openbb[all]) (0.27.1)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp<1.17.0,>=1.12.4->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/lib/python3.12/dist-packages (from mcp<1.17.0,>=1.12.4->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (2.11.0)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp<1.17.0,>=1.12.4->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (3.0.2)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.61.0->pandas-ta-openbb<0.5.0,>=0.4.22->openbb-charting<3.0.0,>=2.4.0->openbb[all]) (0.45.1)
# Requirement already satisfied: isodate in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (0.7.2)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (0.3.4)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (0.7.2)
# Requirement already satisfied: parse in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (1.20.2)
# Requirement already satisfied: werkzeug<3.1.2 in /usr/local/lib/python3.12/dist-packages (from openapi-core>=0.19.5->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (3.1.1)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pydantic[email]>=2.11.7->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (2.3.0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=3.0.0->pytest-freezegun<0.5.0,>=0.4.2->openbb-stockgrid<2.0.0,>=1.5.0->openbb[all]) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=3.0.0->pytest-freezegun<0.5.0,>=0.4.2->openbb-stockgrid<2.0.0,>=1.5.0->openbb[all]) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=3.0.0->pytest-freezegun<0.5.0,>=0.4.2->openbb-stockgrid<2.0.0,>=1.5.0->openbb[all]) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (4.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.6.0->openbb[all]) (75.2.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.12->arch<8.0,>=7.2->openbb-econometrics<2.0.0,>=1.6.0->openbb[all]) (1.0.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.28.1->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (1.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.5.0->openbb[all]) (2.23)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb[all]) (2024.11.6)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.12/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb[all]) (5.3.1)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (2.8.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-core>=0.19.5->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (6.0.3)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-core>=0.19.5->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (0.4.4)
# Requirement already satisfied: lxml_html_clean in /usr/local/lib/python3.12/dist-packages (from lxml[html_clean]>=4.4.2->justext>=3.0.1->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.5.0->openbb[all]) (0.4.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (0.1.2)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-core>=0.19.5->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi-core>=0.19.5->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (1.12.0)
# Requirement already satisfied: docutils in /usr/local/lib/python3.12/dist-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (0.21.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug<3.1.2->openapi-core>=0.19.5->fastmcp>=2.12.3->openbb-mcp-server<2.0.0,>=1.2.0->openbb[all]) (3.0.3)

# %%
# Before running this cell, restart the runtime by selecting, "Restart runtime", from the "Runtime" menu.

# Import statements - for many scenarios, the only import needed will be `from openbb import obb`
from typing import Literal
from IPython.display import display
from IPython.display import clear_output
import ipywidgets as widgets
import pandas as pd
import pandas_ta as ta
from datetime import datetime
from plotly import graph_objects as go

from openbb import obb

# %%
# Login to OpenBB Hub to retrieve stored API keys.
# https://my.openbb.co/app/platform/pat
# https://my.openbb.co/app/platform/api-keys

obb.account.login(pat="replace with your PAT")

# This is not required
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4212367383.py in <cell line: 0>()
#       3 # https://my.openbb.co/app/platform/api-keys
#       4
# ----> 5 obb.account.login(pat="replace with your PAT")
#       6
#       7 # This is not required
#
# AttributeError: 'App' object has no attribute 'account'

# %%
# Verify that the credentials from Hub were loaded successfully.

obb.user.credentials

# %%
# Set the output preference, if desired. The examples below use Pandas DataFrames.

obb.user.preferences.output_type = "dataframe"

# %%
# Get Some Data
symbol = "SPY"

options = obb.derivatives.options.chains(symbol, provider="cboe")

options

# %%
# Prepare A View - Volume and Open Interest by Expiration or Strike

def filter_options_data(options, by: Literal["expiration", "strike"] = "expiration"):
    data = pd.DataFrame()
    data["Total Open Interest"] = options.groupby(by)["open_interest"].sum()
    data["Call Open Interest"] = options[options["option_type"] == "call"].groupby(by)["open_interest"].sum()
    data["Put Open Interest"] = options[options["option_type"] == "put"].groupby(by)["open_interest"].sum()
    data["Total Volume"] = options.groupby(by)["volume"].sum()
    data["Call Volume"] = options[options["option_type"] == "call"].groupby(by)["volume"].sum()
    data["Put Volume"] = options[options["option_type"] == "put"].groupby(by)["volume"].sum()

    return data

data = filter_options_data(options, "strike")

data

# %%
# Do not run this cell if you are following the example above.

# In this scenario, "data" could be anything that would be displayed as a bar chart. Alternatively, it could be company fundamentals data.

# Note: This requires a valid FMP API key


symbol="AAPL"

data = obb.equity.fundamental.ratios(symbol, limit = 100, period="quarter", provider="fmp")

data.index = data.index.strftime("%Y-%m-%d")

data

# %%
# Create a widget for selecting the data to display.

clear_output(wait = False)

data_choices = data.columns.tolist()
data_selection = widgets.Dropdown(
    options = data_choices,
    value = None,
)
output = widgets.Output()


def generate_figure(data, data_choice):
    data = data[data[data_choice].notnull()]
    fig = go.Figure()
    fig.add_bar(
        y = data[data_choice][data[data_choice] > 0].values,
        x = data[data_choice][data[data_choice] > 0].index,
        name = data_choice,
        marker = dict(color = "blue"),
    )
    fig.add_bar(
        y = data[data_choice][data[data_choice] < 0].values,
        x = data[data_choice][data[data_choice] < 0].index,
        name = data_choice,
        marker = dict(color = "red")
    )
    fig.update_xaxes(type="category")
    fig.update_traces(width=0.98, selector=dict(type="bar"))
    fig.update_layout(
        showlegend=False,
        width=1400,
        height=600,
        title = dict(
            text=f"{symbol} {data_choice.replace('_', ' ').title()}",
            xanchor = "center",
            x = 0.5,
            font = dict(size = 20)
        ),
        barmode="overlay",
        bargap=0,
        bargroupgap=0,
        yaxis=dict(
            ticklen=0,
            showgrid=True,
            tickfont=dict(size=14),
        ),
        xaxis=dict(
            showgrid=False,
            autorange=True,
            tickangle=90,
            tickfont=dict(size=11),
        ),
    )
    return fig

def on_value_change(change):
    clear_output(wait = True)
    display(data_selection)
    with output:
        data_selection.value

data_selection.observe(on_value_change, names="value")
display(data_selection)

# Select from the drop-down menu below.

# %%
# Play this cell to display the choice

if data_selection.value is not None:

    generate_figure(data, data_selection.value).show()
